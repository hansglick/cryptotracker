# %%
# Loadding libs
from datetime import datetime
from bs4 import BeautifulSoup
import requests as r
import json
import re
import os, sys
import time
import argparse

# %%
def Grab_Dates_Urls(author):
    
    url = "https://github.com" + "/" + author
    response = r.get(url)
    soup = BeautifulSoup(response.text,"html.parser")
    selector = ".small"
    data = soup.select(selector)
    dates_elements = data[0]
    dates_elements = dates_elements.find_all("li")
    dates_urls = ["https://github.com" + item.find("a")["href"] for item in dates_elements]
    
    return dates_urls

# %%
def Grab_One_Year_Contribution(url):
    
    response = r.get(url)
    soup = BeautifulSoup(response.text,"html.parser")
    selector = ".js-yearly-contributions .mb-2"
    data = soup.select(selector)
    data = data[0]
    x = data.text
    n_contributions = x.split()[0]
    year = x.split()[-1]
    n_contributions = n_contributions.replace(",","")
    n_contributions = int(n_contributions)
    
    return (year,n_contributions)

# %%
def Grab_Author_Contributions(author):

    RES = []
    urls = Grab_Dates_Urls(author)
    for url in urls:
        year,n_contributions = Grab_One_Year_Contribution(url)
        RES.append({"author":author,"year":int(year),"contributions":n_contributions})

    return RES

# %%
def Read_Authors_File(filename):
    
    urls = []
    with open(filename) as file:
        for line in file:
            urls.append(line.rstrip())
    
    return urls

# %%
filename = "contributors.txt"
authors = Read_Authors_File(filename)


print("[")
for idx_author,author in enumerate(authors):
    experience = Grab_Author_Contributions(author)
    for idx_year,item in enumerate(experience):
        print(json.dumps(item, indent=4, sort_keys=True))
        if idx_author+1==len(authors) and (idx_year+1) == len(experience):
            x = 1 + 1
        else:
            print(",")
print("]")
# Out:
# [
# {
#     "author": "chevdor",
#     "contributions": 1480,
#     "year": 2021
# }
# ,
# {
#     "author": "chevdor",
#     "contributions": 188,
#     "year": 2020
# }
# ,
# {
#     "author": "chevdor",
#     "contributions": 64,
#     "year": 2019
# }
# ,
# {
#     "author": "chevdor",
#     "contributions": 248,
#     "year": 2018
# }
# ,
# {
#     "author": "chevdor",
#     "contributions": 163,
#     "year": 2017
# }
# ,
# {
#     "author": "chevdor",
#     "contributions": 266,
#     "year": 2016
# }
# ,
# {
#     "author": "chevdor",
#     "contributions": 318,
#     "year": 2015
# }
# ,
# {
#     "author": "chevdor",
#     "contributions": 117,
#     "year": 2014
# }
# ,
# {
#     "author": "chevdor",
#     "contributions": 0,
#     "year": 2013
# }
# ,
# {
#     "author": "chevdor",
#     "contributions": 0,
#     "year": 2012
# }
# ,
# {
#     "author": "chevdor",
#     "contributions": 1,
#     "year": 2011
# }
# ,
# {
#     "author": "hansglick",
#     "contributions": 144,
#     "year": 2021
# }
# ,
# {
#     "author": "hansglick",
#     "contributions": 71,
#     "year": 2020
# }
# ,
# {
#     "author": "hansglick",
#     "contributions": 89,
#     "year": 2019
# }
# ,
# {
#     "author": "hansglick",
#     "contributions": 0,
#     "year": 2018
# }
# ,
# {
#     "author": "hansglick",
#     "contributions": 15,
#     "year": 2017
# }
# ,
# {
#     "author": "hansglick",
#     "contributions": 1,
#     "year": 2016
# }
# ,
# {
#     "author": "hansglick",
#     "contributions": 2,
#     "year": 2015
# }
# ,
# {
#     "author": "vincentgigliobianco",
#     "contributions": 3,
#     "year": 2021
# }
# ,
# {
#     "author": "vincentgigliobianco",
#     "contributions": 17,
#     "year": 2020
# }
# ,
# {
#     "author": "vincentgigliobianco",
#     "contributions": 129,
#     "year": 2019
# }
# ,
# {
#     "author": "vincentgigliobianco",
#     "contributions": 7,
#     "year": 2018
# }
# ,
# {
#     "author": "vincentgigliobianco",
#     "contributions": 0,
#     "year": 2017
# }
# ,
# {
#     "author": "vincentgigliobianco",
#     "contributions": 0,
#     "year": 2016
# }
# ,
# {
#     "author": "vincentgigliobianco",
#     "contributions": 1,
#     "year": 2015
# }
# ,
# {
#     "author": "RomainTT",
#     "contributions": 22,
#     "year": 2021
# }
# ,
# {
#     "author": "RomainTT",
#     "contributions": 56,
#     "year": 2020
# }
# ,
# {
#     "author": "RomainTT",
#     "contributions": 59,
#     "year": 2019
# }
# ,
# {
#     "author": "RomainTT",
#     "contributions": 112,
#     "year": 2018
# }
# ,
# {
#     "author": "RomainTT",
#     "contributions": 13,
#     "year": 2017
# }
# ,
# {
#     "author": "RomainTT",
#     "contributions": 4,
#     "year": 2016
# }
# ,
# {
#     "author": "RomainTT",
#     "contributions": 5,
#     "year": 2015
# }
# ]
